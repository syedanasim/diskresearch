# %%
exec(open("functions_i_main.py").read())

# %%
exec(open("functions_ii_plot.py").read())

# %%
exec(open("capturedata_manual.py").read())
# Out:
# <string>:453: RuntimeWarning: invalid value encountered in arcsin
# <string>:458: RuntimeWarning: invalid value encountered in arcsin
# <string>:463: RuntimeWarning: invalid value encountered in arcsin
# <string>:287: RuntimeWarning: invalid value encountered in arcsin

# %%
exec(open("capturedata_manual_rgiant.py").read())

# %%
exec(open("capturedata_manual_ostar.py").read())

# %%
exec(open("capturedata_manual_gstar.py").read())

# %%
exec(open("capturedata_manual_mstar.py").read())

# %%
exec(open("capturedata_manual_10sBH.py").read())

# %%
stitch_plot_stellar_i()

# %%
stitch_plot_stellar_a()

# %%
it_acolor_plot_proretro('r_giant')

# %%
it_acolor_plot_proretro('o_star')

# %%
it_acolor_plot_proretro('g_star')

# %%
it_acolor_plot_proretro('m_star')

# %%
stitch_plot_stellar()

# %%
stitch_plot_sBH()

# %%
fig1_plot()

# %%
hprofile_color_plot()
